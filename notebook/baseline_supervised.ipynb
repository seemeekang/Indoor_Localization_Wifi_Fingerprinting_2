# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import lightgbm as lgb

class UJIDataset(torch.utils.data.Dataset):
    def __init__(self, root, train = True, transform = None, target_transform = None, download = False):
        self.root = root
        dir_path = self.root + '/UJIndoorLoc'
        zip_path = self.root + '/uji_uil.zip'
        dataset_training_file = dir_path + '/trainingData.csv'
        dataset_validation_file = dir_path + '/validationData.csv'
        # Load independent variables (WAPs values)
        if train:
            dataset_file = dataset_training_file
        else:
            dataset_file = dataset_validation_file
        file = open(dataset_file, 'r')
        # Load labels
        label = file.readline()
        label = label.split(',')
        # Load independent variables
        file_load = np.loadtxt(file, delimiter = ',', skiprows = 1)
        #file_load_label = np.loadtxt(file, delimiter = ',')
        #data = np.genfromtxt(file, dtype = float, delimiter = ',', names = True)
        # RSSI values
        self.x = file_load[:, 0 : 520]
        # Load dependent variables
        self.y = file_load[:, 520 : 524]
        # Divide labels into x and y
        self.x_label = label[0 : 520]
        self.x_label = np.concatenate([self.x_label, label[524: 529]])
        self.y_label = label[520 : 524]
        # Regularization of independent variables
        self.x[self.x == 100] = np.nan    # WAP not detected
        self.x = self.x + 104             # Convert into positive values
        self.x = self.x / 104             # Regularize into scale between 0 and 1
        # Building ID, Space ID, Relative Position, User ID, Phone ID and Timestamp respectively
        self.x = np.concatenate([self.x, file_load[:, 524 : 529]], axis = 1)
        file.close()
        # Reduce the number of dependent variables by combining building number and floor into one variable: area
        area = self.y[:, 3] * 5 + self.y[:, 2]
        self.y = np.column_stack((self.y, area))
    def to_tensor(self):
        self.x = torch.from_numpy(self.x).float()
        self.y = torch.from_numpy(self.y).float()
        self.area = torch.from_numpy(self.area).float()
    def nan_to_zero(self):
        self.x = np.nan_to_num(self.x)
    # Return the target instance (row)
    def __getitem__(self, index_row):
        return self.x[index_row, :], self.y[index_row, :]
    # Return the number of instances (the number of rows)
    def __len__(self, dim = 0):
        return int(self.x.size()[0])

# %%
# Calculate Euclidean distance (unit: meter) between two coordinates in EPSG:3857 
def euclidean_distance(latitude_1, longitude_1, latitude_2, longitude_2):
    return np.sqrt((latitude_1 - latitude_2)**2 + (longitude_1 - longitude_2)**2)

# %%
# Load training dataset
dataset_train = UJIDataset('./data', train = True)
dataset_test = UJIDataset('./data', train = False)
#gb_train_data = lgb.Dataset(

# %%
x_train, x_validate, y_train, y_validate = sklearn.model_selection.train_test_split(dataset_train.x, dataset_train.y, test_size = 0.2, random_state = 42)
x_test1, x_test2, y_test1, y_test2 = sklearn.model_selection.train_test_split(dataset_test.x, dataset_test.y, test_size = 0.5, random_state = 42)

# %%
dataset_train_reg_long_lgb = lgb.Dataset(x_train, label = y_train[:, 0])
dataset_validate_reg_long_lgb = lgb.Dataset(x_validate, label = y_validate[:, 0])
dataset_train_reg_lat_lgb = lgb.Dataset(x_train, label = y_train[:, 1])
dataset_validate_reg_lat_lgb = lgb.Dataset(x_validate, label = y_validate[:, 1])
dataset_train_cat_floor_lgb = lgb.Dataset(x_train, label = y_train[:, 2])
dataset_validate_cat_floor_lgb = lgb.Dataset(x_validate, label = y_validate[:, 2])
dataset_train_cat_building_lgb = lgb.Dataset(x_train, label = y_train[:, 3])
dataset_validate_cat_building_lgb = lgb.Dataset(x_validate, label = y_validate[:, 3])
dataset_train_cat_area_lgb = lgb.Dataset(x_train, label = y_train[:, 4])
dataset_validate_cat_area_lgb = lgb.Dataset(x_validate, label = y_validate[:, 4])

# %%
params_lgbr = {
              'boosting_type': 'rf',
              'bagging_freq': 5,
              'bagging_fraction': 0.8,
              'num_leaves': 1440,  
              'learning_rate': 0.001,
              'num_boost_rounds': 1000,
              'max_depth': -1,
              'objective': 'regression'
              #'seed':2018
              }

params_lgbr_long_fit = {'eval_set': [(x_validate, y_validate[:, 0])],
                        'eval_names': ['evalset_long'],
                        'eval_metric': ['rmse'],
                        'is_higher_better': False
                        #'early_stoppping_rounds': [100],
                       }

params_lgbr_lat_fit = {'eval_set': [(x_validate, y_validate[:, 1])],
                       'eval_names': ['evalset_lat'],
                       'eval_metric': ['rmse'],
                       'is_higher_better': False,
                        #'early_stoppping_rounds': [100],
                       }

params_lgbc = {'boosting_type': 'rf',
               'bagging_freq': 5,
               'bagging_fraction': 0.8,
               'num_leaves': 144,  
               'learning_rate': 0.002,
               'num_boost_rounds': 1000,
               'max_depth': -1,
               'objective': 'multiclass'
              }

params_lgbc_floor_fit = {'eval_set': [(x_validate, y_validate[:, 2])],
                         'eval_names': ['evalset_floor'],
                         'eval_metric': ['multi_logloss'],
                         'is_higher_better': False,
                         #'early_stopping_rounds': [100],
                        }

params_lgbc_building_fit = {'eval_set': [(x_validate, y_validate[:, 3])],
                            'eval_names': ['evalset_building'],
                            'eval_metric': ['multi_logloss'],
                            'is_higher_better': False,
                            #'early_stoppping_rounds': [100],
                           }



params_lgbc_area_fit = {'eval_set': [(x_validate, y_validate[:, 4])],
                        'eval_names': ['evalset_area'],
                        'eval_metric': ['multi_logloss'],
                        'is_higher_better': False,
                        #'early_stopping_rounds': [100],
                       }

# %%
print(y_train[:,4])
# Out:
# [ 0. 14. 10. ... 10. 13.  0.]

# %%
lgbr_long = lgb.LGBMRegressor(**params_lgbr)
lgbr_lat = lgb.LGBMRegressor(**params_lgbr)
lgbc_floor = lgb.LGBMClassifier(**params_lgbc)
lgbc_building = lgb.LGBMClassifier(**params_lgbc)
lgbc_area = lgb.LGBMClassifier(**params_lgbc)

model_reg_long_lgb_fit = lgbr_long.fit(X = x_train, y = y_train[:, 0], **params_lgbr_long_fit, early_stopping_rounds = 100)
model_reg_lat_lgb_fit = lgbr_lat.fit(X = x_train, y = y_train[:, 1], **params_lgbr_lat_fit, early_stopping_rounds = 100)
model_cat_floor_lgb_fit = lgbc_floor.fit(X = x_train, y = y_train[:, 2], **params_lgbc_floor_fit, early_stopping_rounds = 100)
model_cat_building_lgb_fit = lgbc_building.fit(X = x_train, y = y_train[:, 3], **params_lgbc_building_fit, early_stopping_rounds = 100)
model_cat_area_lgb_fit = lgbc_area.fit(X = x_train, y = y_train[:, 4], **params_lgbc_area_fit, early_stopping_rounds = 100)
# Out:
# [1]	evalset_long's rmse: 7.99773	evalset_long's l2: 63.9637
# Training until validation scores don't improve for 100 rounds
# [2]	evalset_long's rmse: 7.99773	evalset_long's l2: 63.9637
# [3]	evalset_long's rmse: 7.99773	evalset_long's l2: 63.9637
# [4]	evalset_long's rmse: 7.99773	evalset_long's l2: 63.9637
# [5]	evalset_long's rmse: 7.99773	evalset_long's l2: 63.9637
# [6]	evalset_long's rmse: 7.43795	evalset_long's l2: 55.323
# [7]	evalset_long's rmse: 7.21253	evalset_long's l2: 52.0206
# [8]	evalset_long's rmse: 7.14933	evalset_long's l2: 51.113
# [9]	evalset_long's rmse: 7.16498	evalset_long's l2: 51.3369
# [10]	evalset_long's rmse: 7.21817	evalset_long's l2: 52.1019
# [11]	evalset_long's rmse: 7.13357	evalset_long's l2: 50.8878
# [12]	evalset_long's rmse: 7.09878	evalset_long's l2: 50.3927
# [13]	evalset_long's rmse: 7.09512	evalset_long's l2: 50.3407
# [14]	evalset_long's rmse: 7.11082	evalset_long's l2: 50.5637
# [15]	evalset_long's rmse: 7.13841	evalset_long's l2: 50.9568
# [16]	evalset_long's rmse: 6.95699	evalset_long's l2: 48.3997
# [17]	evalset_long's rmse: 6.81872	evalset_long's l2: 46.4949
# [18]	evalset_long's rmse: 6.71405	evalset_long's l2: 45.0785
# [19]	evalset_long's rmse: 6.63565	evalset_long's l2: 44.0319
# [20]	evalset_long's rmse: 6.57786	evalset_long's l2: 43.2683
# [21]	evalset_long's rmse: 6.59803	evalset_long's l2: 43.534
# [22]	evalset_long's rmse: 6.62517	evalset_long's l2: 43.8929
# [23]	evalset_long's rmse: 6.65717	evalset_long's l2: 44.318
# [24]	evalset_long's rmse: 6.69248	evalset_long's l2: 44.7894
# [25]	evalset_long's rmse: 6.72994	evalset_long's l2: 45.2921
# [26]	evalset_long's rmse: 6.75134	evalset_long's l2: 45.5805
# [27]	evalset_long's rmse: 6.7769	evalset_long's l2: 45.9263
# [28]	evalset_long's rmse: 6.80553	evalset_long's l2: 46.3152
# [29]	evalset_long's rmse: 6.83637	evalset_long's l2: 46.7359
# [30]	evalset_long's rmse: 6.86874	evalset_long's l2: 47.1796
# [31]	evalset_long's rmse: 6.87214	evalset_long's l2: 47.2263
# [32]	evalset_long's rmse: 6.87882	evalset_long's l2: 47.3182
# [33]	evalset_long's rmse: 6.88816	evalset_long's l2: 47.4468
# [34]	evalset_long's rmse: 6.89966	evalset_long's l2: 47.6053
# [35]	evalset_long's rmse: 6.91289	evalset_long's l2: 47.788
# [36]	evalset_long's rmse: 6.9278	evalset_long's l2: 47.9944
# [37]	evalset_long's rmse: 6.94498	evalset_long's l2: 48.2328
# [38]	evalset_long's rmse: 6.96401	evalset_long's l2: 48.4975
# [39]	evalset_long's rmse: 6.98451	evalset_long's l2: 48.7834
# [40]	evalset_long's rmse: 7.00618	evalset_long's l2: 49.0865
# [41]	evalset_long's rmse: 7.01434	evalset_long's l2: 49.2009
# [42]	evalset_long's rmse: 7.02407	evalset_long's l2: 49.3376
# [43]	evalset_long's rmse: 7.03513	evalset_long's l2: 49.493
# [44]	evalset_long's rmse: 7.04729	evalset_long's l2: 49.6643
# [45]	evalset_long's rmse: 7.06037	evalset_long's l2: 49.8489
# [46]	evalset_long's rmse: 7.03431	evalset_long's l2: 49.4816
# [47]	evalset_long's rmse: 7.01235	evalset_long's l2: 49.173
# [48]	evalset_long's rmse: 6.99407	evalset_long's l2: 48.917
# [49]	evalset_long's rmse: 6.9791	evalset_long's l2: 48.7078
# [50]	evalset_long's rmse: 6.96711	evalset_long's l2: 48.5406
# [51]	evalset_long's rmse: 6.92216	evalset_long's l2: 47.9164
# [52]	evalset_long's rmse: 6.88122	evalset_long's l2: 47.3512
# [53]	evalset_long's rmse: 6.84397	evalset_long's l2: 46.8399
# [54]	evalset_long's rmse: 6.81011	evalset_long's l2: 46.3776
# [55]	evalset_long's rmse: 6.77939	evalset_long's l2: 45.9601
# [56]	evalset_long's rmse: 6.75715	evalset_long's l2: 45.6591
# [57]	evalset_long's rmse: 6.73775	evalset_long's l2: 45.3973
# [58]	evalset_long's rmse: 6.72095	evalset_long's l2: 45.1712
# [59]	evalset_long's rmse: 6.70654	evalset_long's l2: 44.9776
# [60]	evalset_long's rmse: 6.69431	evalset_long's l2: 44.8138
# [61]	evalset_long's rmse: 6.6389	evalset_long's l2: 44.075
# [62]	evalset_long's rmse: 6.58651	evalset_long's l2: 43.3821
# [63]	evalset_long's rmse: 6.53694	evalset_long's l2: 42.7316
# [64]	evalset_long's rmse: 6.49005	evalset_long's l2: 42.1208
# [65]	evalset_long's rmse: 6.44568	evalset_long's l2: 41.5468
# [66]	evalset_long's rmse: 6.45453	evalset_long's l2: 41.661
# [67]	evalset_long's rmse: 6.46411	evalset_long's l2: 41.7847
# [68]	evalset_long's rmse: 6.47435	evalset_long's l2: 41.9171
# [69]	evalset_long's rmse: 6.48516	evalset_long's l2: 42.0573
# [70]	evalset_long's rmse: 6.49649	evalset_long's l2: 42.2044
# [71]	evalset_long's rmse: 6.50118	evalset_long's l2: 42.2653
# [72]	evalset_long's rmse: 6.50683	evalset_long's l2: 42.3389
# [73]	evalset_long's rmse: 6.51336	evalset_long's l2: 42.4239
# [74]	evalset_long's rmse: 6.52068	evalset_long's l2: 42.5193
# [75]	evalset_long's rmse: 6.52873	evalset_long's l2: 42.6243
# [76]	evalset_long's rmse: 6.53523	evalset_long's l2: 42.7093
# [77]	evalset_long's rmse: 6.54246	evalset_long's l2: 42.8038
# [78]	evalset_long's rmse: 6.55036	evalset_long's l2: 42.9072
# [79]	evalset_long's rmse: 6.55885	evalset_long's l2: 43.0186
# [80]	evalset_long's rmse: 6.5679	evalset_long's l2: 43.1373
# [81]	evalset_long's rmse: 6.57549	evalset_long's l2: 43.2371
# [82]	evalset_long's rmse: 6.58354	evalset_long's l2: 43.343
# [83]	evalset_long's rmse: 6.59199	evalset_long's l2: 43.4543
# [84]	evalset_long's rmse: 6.60081	evalset_long's l2: 43.5707
# [85]	evalset_long's rmse: 6.60997	evalset_long's l2: 43.6917
# [86]	evalset_long's rmse: 6.622	evalset_long's l2: 43.8509
# [87]	evalset_long's rmse: 6.6342	evalset_long's l2: 44.0127
# [88]	evalset_long's rmse: 6.64656	evalset_long's l2: 44.1767
# [89]	evalset_long's rmse: 6.65903	evalset_long's l2: 44.3427
# [90]	evalset_long's rmse: 6.67162	evalset_long's l2: 44.5105
# [91]	evalset_long's rmse: 6.66038	evalset_long's l2: 44.3606
# [92]	evalset_long's rmse: 6.65011	evalset_long's l2: 44.224
# [93]	evalset_long's rmse: 6.64077	evalset_long's l2: 44.0999
# [94]	evalset_long's rmse: 6.63232	evalset_long's l2: 43.9876
# [95]	evalset_long's rmse: 6.62469	evalset_long's l2: 43.8865
# [96]	evalset_long's rmse: 6.61756	evalset_long's l2: 43.7921
# [97]	evalset_long's rmse: 6.61105	evalset_long's l2: 43.706
# [98]	evalset_long's rmse: 6.60513	evalset_long's l2: 43.6277
# [99]	evalset_long's rmse: 6.59976	evalset_long's l2: 43.5568
# [100]	evalset_long's rmse: 6.59492	evalset_long's l2: 43.493
# Did not meet early stopping. Best iteration is:
# [65]	evalset_long's rmse: 6.44568	evalset_long's l2: 41.5468
# [1]	evalset_lat's rmse: 6.87808	evalset_lat's l2: 47.308
# Training until validation scores don't improve for 100 rounds
# [2]	evalset_lat's rmse: 6.87808	evalset_lat's l2: 47.308
# [3]	evalset_lat's rmse: 6.87808	evalset_lat's l2: 47.308
# [4]	evalset_lat's rmse: 6.87808	evalset_lat's l2: 47.308
# [5]	evalset_lat's rmse: 6.87808	evalset_lat's l2: 47.308
# [6]	evalset_lat's rmse: 6.52255	evalset_lat's l2: 42.5436
# [7]	evalset_lat's rmse: 6.33199	evalset_lat's l2: 40.0941
# [8]	evalset_lat's rmse: 6.22724	evalset_lat's l2: 38.7785
# [9]	evalset_lat's rmse: 6.16963	evalset_lat's l2: 38.0644
# [10]	evalset_lat's rmse: 6.13903	evalset_lat's l2: 37.6877
# [11]	evalset_lat's rmse: 6.03032	evalset_lat's l2: 36.3648
# [12]	evalset_lat's rmse: 5.96995	evalset_lat's l2: 35.6402
# [13]	evalset_lat's rmse: 5.941	evalset_lat's l2: 35.2955
# [14]	evalset_lat's rmse: 5.93259	evalset_lat's l2: 35.1957
# [15]	evalset_lat's rmse: 5.93762	evalset_lat's l2: 35.2554
# [16]	evalset_lat's rmse: 5.90741	evalset_lat's l2: 34.8975
# [17]	evalset_lat's rmse: 5.89344	evalset_lat's l2: 34.7327
# [18]	evalset_lat's rmse: 5.8911	evalset_lat's l2: 34.705
# [19]	evalset_lat's rmse: 5.89704	evalset_lat's l2: 34.7751
# [20]	evalset_lat's rmse: 5.90887	evalset_lat's l2: 34.9147
# [21]	evalset_lat's rmse: 5.82855	evalset_lat's l2: 33.972
# [22]	evalset_lat's rmse: 5.76496	evalset_lat's l2: 33.2348
# [23]	evalset_lat's rmse: 5.71501	evalset_lat's l2: 32.6613
# [24]	evalset_lat's rmse: 5.67619	evalset_lat's l2: 32.2192
# [25]	evalset_lat's rmse: 5.6465	evalset_lat's l2: 31.883
# [26]	evalset_lat's rmse: 5.60981	evalset_lat's l2: 31.47
# [27]	evalset_lat's rmse: 5.58061	evalset_lat's l2: 31.1432
# [28]	evalset_lat's rmse: 5.55767	evalset_lat's l2: 30.8877
# [29]	evalset_lat's rmse: 5.53997	evalset_lat's l2: 30.6913
# [30]	evalset_lat's rmse: 5.52666	evalset_lat's l2: 30.544
# [31]	evalset_lat's rmse: 5.47705	evalset_lat's l2: 29.9981
# [32]	evalset_lat's rmse: 5.43576	evalset_lat's l2: 29.5475
# [33]	evalset_lat's rmse: 5.40167	evalset_lat's l2: 29.1781
# [34]	evalset_lat's rmse: 5.37383	evalset_lat's l2: 28.8781
# [35]	evalset_lat's rmse: 5.35141	evalset_lat's l2: 28.6376
# [36]	evalset_lat's rmse: 5.30554	evalset_lat's l2: 28.1487
# [37]	evalset_lat's rmse: 5.26699	evalset_lat's l2: 27.7411
# [38]	evalset_lat's rmse: 5.23491	evalset_lat's l2: 27.4042
# [39]	evalset_lat's rmse: 5.20854	evalset_lat's l2: 27.1289
# [40]	evalset_lat's rmse: 5.18721	evalset_lat's l2: 26.9072
# [41]	evalset_lat's rmse: 5.16592	evalset_lat's l2: 26.6867
# [42]	evalset_lat's rmse: 5.14855	evalset_lat's l2: 26.5076
# [43]	evalset_lat's rmse: 5.13465	evalset_lat's l2: 26.3647
# [44]	evalset_lat's rmse: 5.12384	evalset_lat's l2: 26.2537
# [45]	evalset_lat's rmse: 5.11576	evalset_lat's l2: 26.171
# [46]	evalset_lat's rmse: 5.13407	evalset_lat's l2: 26.3587
# [47]	evalset_lat's rmse: 5.15394	evalset_lat's l2: 26.5631
# [48]	evalset_lat's rmse: 5.17508	evalset_lat's l2: 26.7815
# [49]	evalset_lat's rmse: 5.19728	evalset_lat's l2: 27.0117
# [50]	evalset_lat's rmse: 5.22034	evalset_lat's l2: 27.2519
# [51]	evalset_lat's rmse: 5.20181	evalset_lat's l2: 27.0588
# [52]	evalset_lat's rmse: 5.18573	evalset_lat's l2: 26.8918
# [53]	evalset_lat's rmse: 5.17188	evalset_lat's l2: 26.7484
# [54]	evalset_lat's rmse: 5.16006	evalset_lat's l2: 26.6262
# [55]	evalset_lat's rmse: 5.15009	evalset_lat's l2: 26.5234
# [56]	evalset_lat's rmse: 5.15818	evalset_lat's l2: 26.6068
# [57]	evalset_lat's rmse: 5.16747	evalset_lat's l2: 26.7027
# [58]	evalset_lat's rmse: 5.1778	evalset_lat's l2: 26.8096
# [59]	evalset_lat's rmse: 5.18905	evalset_lat's l2: 26.9263
# [60]	evalset_lat's rmse: 5.20111	evalset_lat's l2: 27.0516
# [61]	evalset_lat's rmse: 5.20081	evalset_lat's l2: 27.0485
# [62]	evalset_lat's rmse: 5.20129	evalset_lat's l2: 27.0534
# [63]	evalset_lat's rmse: 5.20246	evalset_lat's l2: 27.0656
# [64]	evalset_lat's rmse: 5.20427	evalset_lat's l2: 27.0844
# [65]	evalset_lat's rmse: 5.20664	evalset_lat's l2: 27.1091
# [66]	evalset_lat's rmse: 5.20712	evalset_lat's l2: 27.1141
# [67]	evalset_lat's rmse: 5.20825	evalset_lat's l2: 27.1259
# [68]	evalset_lat's rmse: 5.20999	evalset_lat's l2: 27.144
# [69]	evalset_lat's rmse: 5.21228	evalset_lat's l2: 27.1679
# [70]	evalset_lat's rmse: 5.21507	evalset_lat's l2: 27.1969
# [71]	evalset_lat's rmse: 5.20541	evalset_lat's l2: 27.0963
# [72]	evalset_lat's rmse: 5.1969	evalset_lat's l2: 27.0078
# [73]	evalset_lat's rmse: 5.18947	evalset_lat's l2: 26.9306
# [74]	evalset_lat's rmse: 5.18304	evalset_lat's l2: 26.8639
# [75]	evalset_lat's rmse: 5.17753	evalset_lat's l2: 26.8069
# [76]	evalset_lat's rmse: 5.18498	evalset_lat's l2: 26.884
# [77]	evalset_lat's rmse: 5.19306	evalset_lat's l2: 26.9679
# [78]	evalset_lat's rmse: 5.20173	evalset_lat's l2: 27.058
# [79]	evalset_lat's rmse: 5.21091	evalset_lat's l2: 27.1536
# [80]	evalset_lat's rmse: 5.22057	evalset_lat's l2: 27.2544
# [81]	evalset_lat's rmse: 5.2253	evalset_lat's l2: 27.3038
# [82]	evalset_lat's rmse: 5.23038	evalset_lat's l2: 27.3569
# [83]	evalset_lat's rmse: 5.23579	evalset_lat's l2: 27.4135
# [84]	evalset_lat's rmse: 5.24149	evalset_lat's l2: 27.4733
# [85]	evalset_lat's rmse: 5.24747	evalset_lat's l2: 27.5359
# [86]	evalset_lat's rmse: 5.24889	evalset_lat's l2: 27.5508
# [87]	evalset_lat's rmse: 5.25087	evalset_lat's l2: 27.5717
# [88]	evalset_lat's rmse: 5.25338	evalset_lat's l2: 27.598
# [89]	evalset_lat's rmse: 5.25638	evalset_lat's l2: 27.6296
# [90]	evalset_lat's rmse: 5.25984	evalset_lat's l2: 27.6659
# [91]	evalset_lat's rmse: 5.24532	evalset_lat's l2: 27.5134
# [92]	evalset_lat's rmse: 5.2319	evalset_lat's l2: 27.3728
# [93]	evalset_lat's rmse: 5.21954	evalset_lat's l2: 27.2435
# [94]	evalset_lat's rmse: 5.20816	evalset_lat's l2: 27.1249
# [95]	evalset_lat's rmse: 5.19773	evalset_lat's l2: 27.0164
# [96]	evalset_lat's rmse: 5.20257	evalset_lat's l2: 27.0667
# [97]	evalset_lat's rmse: 5.20765	evalset_lat's l2: 27.1196
# [98]	evalset_lat's rmse: 5.21296	evalset_lat's l2: 27.1749
# [99]	evalset_lat's rmse: 5.21847	evalset_lat's l2: 27.2324
# [100]	evalset_lat's rmse: 5.22417	evalset_lat's l2: 27.2919
# Did not meet early stopping. Best iteration is:
# [45]	evalset_lat's rmse: 5.11576	evalset_lat's l2: 26.171
# [1]	evalset_floor's multi_logloss: 0.267549
# Training until validation scores don't improve for 100 rounds
# [2]	evalset_floor's multi_logloss: 0.267549
# [3]	evalset_floor's multi_logloss: 0.267549
# [4]	evalset_floor's multi_logloss: 0.267549
# [5]	evalset_floor's multi_logloss: 0.267549
# [6]	evalset_floor's multi_logloss: 0.262208
# [7]	evalset_floor's multi_logloss: 0.259638
# [8]	evalset_floor's multi_logloss: 0.258387
# [9]	evalset_floor's multi_logloss: 0.257814
# [10]	evalset_floor's multi_logloss: 0.257611
# [11]	evalset_floor's multi_logloss: 0.255099
# [12]	evalset_floor's multi_logloss: 0.2534
# [13]	evalset_floor's multi_logloss: 0.252243
# [14]	evalset_floor's multi_logloss: 0.251455
# [15]	evalset_floor's multi_logloss: 0.25092
# [16]	evalset_floor's multi_logloss: 0.250172
# [17]	evalset_floor's multi_logloss: 0.24968
# [18]	evalset_floor's multi_logloss: 0.249378
# [19]	evalset_floor's multi_logloss: 0.24922
# [20]	evalset_floor's multi_logloss: 0.249171
# [21]	evalset_floor's multi_logloss: 0.248668
# [22]	evalset_floor's multi_logloss: 0.248294
# [23]	evalset_floor's multi_logloss: 0.24802
# [24]	evalset_floor's multi_logloss: 0.247827
# [25]	evalset_floor's multi_logloss: 0.247698
# [26]	evalset_floor's multi_logloss: 0.247471
# [27]	evalset_floor's multi_logloss: 0.247308
# [28]	evalset_floor's multi_logloss: 0.247198
# [29]	evalset_floor's multi_logloss: 0.247131
# [30]	evalset_floor's multi_logloss: 0.247099
# [31]	evalset_floor's multi_logloss: 0.246962
# [32]	evalset_floor's multi_logloss: 0.246865
# [33]	evalset_floor's multi_logloss: 0.2468
# [34]	evalset_floor's multi_logloss: 0.246763
# [35]	evalset_floor's multi_logloss: 0.24675
# [36]	evalset_floor's multi_logloss: 0.24677
# [37]	evalset_floor's multi_logloss: 0.246812
# [38]	evalset_floor's multi_logloss: 0.246873
# [39]	evalset_floor's multi_logloss: 0.246949
# [40]	evalset_floor's multi_logloss: 0.247038
# [41]	evalset_floor's multi_logloss: 0.24691
# [42]	evalset_floor's multi_logloss: 0.246801
# [43]	evalset_floor's multi_logloss: 0.246711
# [44]	evalset_floor's multi_logloss: 0.246636
# [45]	evalset_floor's multi_logloss: 0.246575
# [46]	evalset_floor's multi_logloss: 0.246476
# [47]	evalset_floor's multi_logloss: 0.246394
# [48]	evalset_floor's multi_logloss: 0.246327
# [49]	evalset_floor's multi_logloss: 0.246275
# [50]	evalset_floor's multi_logloss: 0.246235
# [51]	evalset_floor's multi_logloss: 0.246284
# [52]	evalset_floor's multi_logloss: 0.246343
# [53]	evalset_floor's multi_logloss: 0.246413
# [54]	evalset_floor's multi_logloss: 0.246491
# [55]	evalset_floor's multi_logloss: 0.246578
# [56]	evalset_floor's multi_logloss: 0.24652
# [57]	evalset_floor's multi_logloss: 0.246472
# [58]	evalset_floor's multi_logloss: 0.246434
# [59]	evalset_floor's multi_logloss: 0.246406
# [60]	evalset_floor's multi_logloss: 0.246385
# [61]	evalset_floor's multi_logloss: 0.246403
# [62]	evalset_floor's multi_logloss: 0.246429
# [63]	evalset_floor's multi_logloss: 0.246462
# [64]	evalset_floor's multi_logloss: 0.246502
# [65]	evalset_floor's multi_logloss: 0.246548
# [66]	evalset_floor's multi_logloss: 0.246562
# [67]	evalset_floor's multi_logloss: 0.246583
# [68]	evalset_floor's multi_logloss: 0.246608
# [69]	evalset_floor's multi_logloss: 0.246638
# [70]	evalset_floor's multi_logloss: 0.246673
# [71]	evalset_floor's multi_logloss: 0.246605
# [72]	evalset_floor's multi_logloss: 0.246546
# [73]	evalset_floor's multi_logloss: 0.246495
# [74]	evalset_floor's multi_logloss: 0.246451
# [75]	evalset_floor's multi_logloss: 0.246415
# [76]	evalset_floor's multi_logloss: 0.24643
# [77]	evalset_floor's multi_logloss: 0.246449
# [78]	evalset_floor's multi_logloss: 0.246473
# [79]	evalset_floor's multi_logloss: 0.2465
# [80]	evalset_floor's multi_logloss: 0.246531
# [81]	evalset_floor's multi_logloss: 0.246441
# [82]	evalset_floor's multi_logloss: 0.24636
# [83]	evalset_floor's multi_logloss: 0.246286
# [84]	evalset_floor's multi_logloss: 0.246219
# [85]	evalset_floor's multi_logloss: 0.246158
# [86]	evalset_floor's multi_logloss: 0.246177
# [87]	evalset_floor's multi_logloss: 0.246198
# [88]	evalset_floor's multi_logloss: 0.246223
# [89]	evalset_floor's multi_logloss: 0.246252
# [90]	evalset_floor's multi_logloss: 0.246283
# [91]	evalset_floor's multi_logloss: 0.246225
# [92]	evalset_floor's multi_logloss: 0.246173
# [93]	evalset_floor's multi_logloss: 0.246125
# [94]	evalset_floor's multi_logloss: 0.246082
# [95]	evalset_floor's multi_logloss: 0.246043
# [96]	evalset_floor's multi_logloss: 0.246087
# [97]	evalset_floor's multi_logloss: 0.246132
# [98]	evalset_floor's multi_logloss: 0.24618
# [99]	evalset_floor's multi_logloss: 0.24623
# [100]	evalset_floor's multi_logloss: 0.246282
# Did not meet early stopping. Best iteration is:
# [95]	evalset_floor's multi_logloss: 0.246043
# [1]	evalset_building's multi_logloss: 0.182637
# Training until validation scores don't improve for 100 rounds
# [2]	evalset_building's multi_logloss: 0.182637
# [3]	evalset_building's multi_logloss: 0.182637
# [4]	evalset_building's multi_logloss: 0.182637
# [5]	evalset_building's multi_logloss: 0.182637
# [6]	evalset_building's multi_logloss: 0.182445
# [7]	evalset_building's multi_logloss: 0.182398
# [8]	evalset_building's multi_logloss: 0.182414
# [9]	evalset_building's multi_logloss: 0.182459
# [10]	evalset_building's multi_logloss: 0.182516
# [11]	evalset_building's multi_logloss: 0.182513
# [12]	evalset_building's multi_logloss: 0.182524
# [13]	evalset_building's multi_logloss: 0.182543
# [14]	evalset_building's multi_logloss: 0.182566
# [15]	evalset_building's multi_logloss: 0.182591
# [16]	evalset_building's multi_logloss: 0.182454
# [17]	evalset_building's multi_logloss: 0.182341
# [18]	evalset_building's multi_logloss: 0.182247
# [19]	evalset_building's multi_logloss: 0.182169
# [20]	evalset_building's multi_logloss: 0.182103
# [21]	evalset_building's multi_logloss: 0.182102
# [22]	evalset_building's multi_logloss: 0.182105
# [23]	evalset_building's multi_logloss: 0.182112
# [24]	evalset_building's multi_logloss: 0.182122
# [25]	evalset_building's multi_logloss: 0.182133
# [26]	evalset_building's multi_logloss: 0.18208
# [27]	evalset_building's multi_logloss: 0.182033
# [28]	evalset_building's multi_logloss: 0.181991
# [29]	evalset_building's multi_logloss: 0.181955
# [30]	evalset_building's multi_logloss: 0.181922
# [31]	evalset_building's multi_logloss: 0.181881
# [32]	evalset_building's multi_logloss: 0.181846
# [33]	evalset_building's multi_logloss: 0.181816
# [34]	evalset_building's multi_logloss: 0.181791
# [35]	evalset_building's multi_logloss: 0.181769
# [36]	evalset_building's multi_logloss: 0.181743
# [37]	evalset_building's multi_logloss: 0.18172
# [38]	evalset_building's multi_logloss: 0.1817
# [39]	evalset_building's multi_logloss: 0.181682
# [40]	evalset_building's multi_logloss: 0.181666
# [41]	evalset_building's multi_logloss: 0.181641
# [42]	evalset_building's multi_logloss: 0.181618
# [43]	evalset_building's multi_logloss: 0.181597
# [44]	evalset_building's multi_logloss: 0.181579
# [45]	evalset_building's multi_logloss: 0.181562
# [46]	evalset_building's multi_logloss: 0.181552
# [47]	evalset_building's multi_logloss: 0.181545
# [48]	evalset_building's multi_logloss: 0.181539
# [49]	evalset_building's multi_logloss: 0.181534
# [50]	evalset_building's multi_logloss: 0.18153
# [51]	evalset_building's multi_logloss: 0.181508
# [52]	evalset_building's multi_logloss: 0.181489
# [53]	evalset_building's multi_logloss: 0.181471
# [54]	evalset_building's multi_logloss: 0.181456
# [55]	evalset_building's multi_logloss: 0.181442
# [56]	evalset_building's multi_logloss: 0.18144
# [57]	evalset_building's multi_logloss: 0.18144
# [58]	evalset_building's multi_logloss: 0.18144
# [59]	evalset_building's multi_logloss: 0.181441
# [60]	evalset_building's multi_logloss: 0.181442
# [61]	evalset_building's multi_logloss: 0.181434
# [62]	evalset_building's multi_logloss: 0.181427
# [63]	evalset_building's multi_logloss: 0.18142
# [64]	evalset_building's multi_logloss: 0.181415
# [65]	evalset_building's multi_logloss: 0.181409
# [66]	evalset_building's multi_logloss: 0.181423
# [67]	evalset_building's multi_logloss: 0.181437
# [68]	evalset_building's multi_logloss: 0.181452
# [69]	evalset_building's multi_logloss: 0.181466
# [70]	evalset_building's multi_logloss: 0.181481
# [71]	evalset_building's multi_logloss: 0.181472
# [72]	evalset_building's multi_logloss: 0.181463
# [73]	evalset_building's multi_logloss: 0.181456
# [74]	evalset_building's multi_logloss: 0.181449
# [75]	evalset_building's multi_logloss: 0.181444
# [76]	evalset_building's multi_logloss: 0.181448
# [77]	evalset_building's multi_logloss: 0.181451
# [78]	evalset_building's multi_logloss: 0.181455
# [79]	evalset_building's multi_logloss: 0.18146
# [80]	evalset_building's multi_logloss: 0.181464
# [81]	evalset_building's multi_logloss: 0.181476
# [82]	evalset_building's multi_logloss: 0.181487
# [83]	evalset_building's multi_logloss: 0.181499
# [84]	evalset_building's multi_logloss: 0.18151
# [85]	evalset_building's multi_logloss: 0.181522
# [86]	evalset_building's multi_logloss: 0.181514
# [87]	evalset_building's multi_logloss: 0.181507
# [88]	evalset_building's multi_logloss: 0.1815
# [89]	evalset_building's multi_logloss: 0.181494
# [90]	evalset_building's multi_logloss: 0.181488
# [91]	evalset_building's multi_logloss: 0.181492
# [92]	evalset_building's multi_logloss: 0.181497
# [93]	evalset_building's multi_logloss: 0.181502
# [94]	evalset_building's multi_logloss: 0.181507
# [95]	evalset_building's multi_logloss: 0.181512
# [96]	evalset_building's multi_logloss: 0.181521
# [97]	evalset_building's multi_logloss: 0.18153
# [98]	evalset_building's multi_logloss: 0.181539
# [99]	evalset_building's multi_logloss: 0.181549
# [100]	evalset_building's multi_logloss: 0.181558
# Did not meet early stopping. Best iteration is:
# [65]	evalset_building's multi_logloss: 0.181409
# [1]	evalset_area's multi_logloss: 0.12713
# Training until validation scores don't improve for 100 rounds
# [2]	evalset_area's multi_logloss: 0.12713
# [3]	evalset_area's multi_logloss: 0.12713
# [4]	evalset_area's multi_logloss: 0.12713
# [5]	evalset_area's multi_logloss: 0.12713
# [6]	evalset_area's multi_logloss: 0.116285
# [7]	evalset_area's multi_logloss: 0.111155
# [8]	evalset_area's multi_logloss: 0.108748
# [9]	evalset_area's multi_logloss: 0.107712
# [10]	evalset_area's multi_logloss: 0.107398
# [11]	evalset_area's multi_logloss: 0.104261
# [12]	evalset_area's multi_logloss: 0.102308
# [13]	evalset_area's multi_logloss: 0.101143
# [14]	evalset_area's multi_logloss: 0.100507
# [15]	evalset_area's multi_logloss: 0.100228
# [16]	evalset_area's multi_logloss: 0.0983776
# [17]	evalset_area's multi_logloss: 0.0970322
# [18]	evalset_area's multi_logloss: 0.0960659
# [19]	evalset_area's multi_logloss: 0.0953867
# [20]	evalset_area's multi_logloss: 0.0949267
# [21]	evalset_area's multi_logloss: 0.0939073
# [22]	evalset_area's multi_logloss: 0.0931236
# [23]	evalset_area's multi_logloss: 0.0925307
# [24]	evalset_area's multi_logloss: 0.0920934
# [25]	evalset_area's multi_logloss: 0.0917838
# [26]	evalset_area's multi_logloss: 0.0912962
# [27]	evalset_area's multi_logloss: 0.0909434
# [28]	evalset_area's multi_logloss: 0.0907022
# [29]	evalset_area's multi_logloss: 0.0905536
# [30]	evalset_area's multi_logloss: 0.0904819
# [31]	evalset_area's multi_logloss: 0.0902857
# [32]	evalset_area's multi_logloss: 0.0901538
# [33]	evalset_area's multi_logloss: 0.0900765
# [34]	evalset_area's multi_logloss: 0.0900455
# [35]	evalset_area's multi_logloss: 0.0900539
# [36]	evalset_area's multi_logloss: 0.0895698
# [37]	evalset_area's multi_logloss: 0.0891632
# [38]	evalset_area's multi_logloss: 0.0888247
# [39]	evalset_area's multi_logloss: 0.0885461
# [40]	evalset_area's multi_logloss: 0.0883203
# [41]	evalset_area's multi_logloss: 0.0879419
# [42]	evalset_area's multi_logloss: 0.0876151
# [43]	evalset_area's multi_logloss: 0.0873342
# [44]	evalset_area's multi_logloss: 0.0870942
# [45]	evalset_area's multi_logloss: 0.0868906
# [46]	evalset_area's multi_logloss: 0.086671
# [47]	evalset_area's multi_logloss: 0.0864887
# [48]	evalset_area's multi_logloss: 0.0863402
# [49]	evalset_area's multi_logloss: 0.0862222
# [50]	evalset_area's multi_logloss: 0.086132
# [51]	evalset_area's multi_logloss: 0.0860991
# [52]	evalset_area's multi_logloss: 0.0860884
# [53]	evalset_area's multi_logloss: 0.0860975
# [54]	evalset_area's multi_logloss: 0.0861245
# [55]	evalset_area's multi_logloss: 0.0861676
# [56]	evalset_area's multi_logloss: 0.0861747
# [57]	evalset_area's multi_logloss: 0.0861982
# [58]	evalset_area's multi_logloss: 0.0862364
# [59]	evalset_area's multi_logloss: 0.086288
# [60]	evalset_area's multi_logloss: 0.0863518
# [61]	evalset_area's multi_logloss: 0.0862067
# [62]	evalset_area's multi_logloss: 0.0860808
# [63]	evalset_area's multi_logloss: 0.0859728
# [64]	evalset_area's multi_logloss: 0.0858812
# [65]	evalset_area's multi_logloss: 0.0858047
# [66]	evalset_area's multi_logloss: 0.0856531
# [67]	evalset_area's multi_logloss: 0.085519
# [68]	evalset_area's multi_logloss: 0.0854012
# [69]	evalset_area's multi_logloss: 0.0852985
# [70]	evalset_area's multi_logloss: 0.08521
# [71]	evalset_area's multi_logloss: 0.0852593
# [72]	evalset_area's multi_logloss: 0.0853185
# [73]	evalset_area's multi_logloss: 0.0853868
# [74]	evalset_area's multi_logloss: 0.0854636
# [75]	evalset_area's multi_logloss: 0.0855482
# [76]	evalset_area's multi_logloss: 0.0855548
# [77]	evalset_area's multi_logloss: 0.0855685
# [78]	evalset_area's multi_logloss: 0.0855887
# [79]	evalset_area's multi_logloss: 0.0856151
# [80]	evalset_area's multi_logloss: 0.0856473
# [81]	evalset_area's multi_logloss: 0.0857511
# [82]	evalset_area's multi_logloss: 0.0858595
# [83]	evalset_area's multi_logloss: 0.0859724
# [84]	evalset_area's multi_logloss: 0.0860893
# [85]	evalset_area's multi_logloss: 0.0862101
# [86]	evalset_area's multi_logloss: 0.0861557
# [87]	evalset_area's multi_logloss: 0.0861096
# [88]	evalset_area's multi_logloss: 0.0860711
# [89]	evalset_area's multi_logloss: 0.0860399
# [90]	evalset_area's multi_logloss: 0.0860156
# [91]	evalset_area's multi_logloss: 0.0858269
# [92]	evalset_area's multi_logloss: 0.0856508
# [93]	evalset_area's multi_logloss: 0.0854865
# [94]	evalset_area's multi_logloss: 0.0853337
# [95]	evalset_area's multi_logloss: 0.0851918
# [96]	evalset_area's multi_logloss: 0.0851634
# [97]	evalset_area's multi_logloss: 0.085142
# [98]	evalset_area's multi_logloss: 0.0851271
# [99]	evalset_area's multi_logloss: 0.0851183
# [100]	evalset_area's multi_logloss: 0.0851155
# Did not meet early stopping. Best iteration is:
# [100]	evalset_area's multi_logloss: 0.0851155

# %%
predict_long_test1_fit = model_reg_long_lgb_fit.predict(x_test1, num_iteration)
predict_lat_test1_fit = model_reg_lat_lgb_fit.predict(x_test1)
predict_floor_test1_fit = model_cat_floor_lgb_fit.predict_proba(x_test1)
predict_building_test1_fit = model_cat_building_lgb_fit.predict_proba(x_test1)
predict_area_test1_fit = model_cat_area_lgb_fit.predict_proba(x_test1)

# %%
print(predict_long_test1_fit)
# Out:
# [-7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7507.78628931 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7504.62996168 -7520.12502064 -7520.12502064
#  -7520.12502064 -7481.46294116 -7520.12502064 -7520.12502064
#  -7520.12502064 -7528.31288934 -7522.86386272 -7520.12502064
#  -7486.57888778 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7484.63003734 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7527.46959222 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7499.14443206 -7520.12502064 -7520.12502064 -7526.50899271
#  -7503.40531948 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7518.90083534 -7520.12502064
#  -7522.42408399 -7497.81394687 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7522.86386272 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7507.11057993 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7483.37283854
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7516.64031577 -7520.12502064 -7530.56706576 -7520.12502064
#  -7528.86458409 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7523.89861828 -7494.21239267 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7532.1179166  -7520.12502064 -7513.40707847
#  -7520.12502064 -7522.86386272 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7532.91716894 -7527.46959222 -7503.87734262 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7522.86386272 -7529.2550797
#  -7520.12502064 -7520.12502064 -7525.45992634 -7520.12502064
#  -7520.12502064 -7517.78951315 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7494.65889149 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7527.71804418 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7503.40531948 -7520.12502064 -7525.83754842 -7523.41700737
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7517.78951315
#  -7520.12502064 -7520.12502064 -7520.12502064 -7496.80892458
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7492.14696259 -7520.12502064
#  -7494.21239267 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7530.58088108 -7487.30996423 -7523.05160171 -7520.12502064
#  -7520.12502064 -7509.88125705 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7525.83967504
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7523.02053011 -7520.12502064 -7528.47848578 -7520.12502064
#  -7520.12502064 -7532.1179166  -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7530.1933851  -7520.12502064
#  -7520.12502064 -7526.73970957 -7509.64831325 -7520.12502064
#  -7520.12502064 -7516.89178333 -7520.12502064 -7522.86386272
#  -7504.31160371 -7532.1179166  -7520.12502064 -7520.12502064
#  -7504.31160371 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7527.46959222 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7532.91716894
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7496.80892458 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7486.49544191 -7520.12502064 -7520.12502064 -7522.42408399
#  -7520.12502064 -7520.12502064 -7520.12502064 -7529.64257568
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7523.58817389 -7520.12502064 -7522.86386272
#  -7499.73660969 -7520.12502064 -7512.00702562 -7507.11057993
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7491.81341675 -7520.12502064 -7520.12502064 -7503.40531948
#  -7517.71254059 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7518.43565131 -7531.73042061 -7522.42408399
#  -7520.12502064 -7520.12502064 -7511.82924003 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7502.7701103  -7520.12502064 -7520.12502064
#  -7508.90855675 -7520.12502064 -7503.40531948 -7520.12502064
#  -7497.28840503 -7520.12502064 -7520.12502064 -7520.12502064
#  -7494.57202121 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7519.89715617 -7529.64257568
#  -7520.12502064 -7520.12502064 -7520.12502064 -7510.28352243
#  -7526.93728722 -7520.12502064 -7520.12502064 -7487.49015952
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7503.05763642 -7520.12502064
#  -7520.12502064 -7520.12502064 -7495.55159142 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.24831555 -7527.37617018
#  -7520.12502064 -7520.12502064 -7520.12502064 -7507.42257617
#  -7520.12502064 -7532.1179166  -7520.12502064 -7520.12502064
#  -7528.86458409 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7528.02441796 -7520.12502064 -7503.40531948
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7522.42408399 -7520.12502064
#  -7522.86386272 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7487.31122878 -7520.12502064
#  -7503.40531948 -7520.12502064 -7520.12502064 -7529.64257568
#  -7530.95382669 -7520.12502064 -7520.12502064 -7502.85990278
#  -7520.12502064 -7520.12502064 -7520.12502064 -7487.30996423
#  -7519.02084676 -7520.12502064 -7506.35775161 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7519.02084676 -7522.86386272
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7522.86386272
#  -7520.12502064 -7519.02084676 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7481.16226273
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7519.02084676 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7496.80892458
#  -7482.08718383 -7487.31122878 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7520.12502064 -7520.12502064
#  -7520.12502064 -7520.12502064 -7484.7337381 ]

# %%
error_building_test1_fit = []
error_floor_test1_fit = []
error_area_test1_fit = []
predict_floor_argmax_test1_fit = predict_floor_test1_fit.argmax(axis = 1)
predict_building_argmax_test1_fit = predict_building_test1_fit.argmax(axis = 1)
predict_area_argmax_test1_fit = predict_area_test1_fit.argmax(axis = 1)
for i in range(len(predict_floor_test1_fit)):
    if predict_floor_argmax_test1_fit[i] != y_test1[i, 2]:
        error_floor_test1_fit.append(i)
    if predict_building_argmax_test1_fit[i] != y_test1[i, 3]:
        error_building_test1_fit.append(i)
    if predict_area_argmax_test1_fit[i] != y_test1[i, 4]:
        error_area_test1_fit.append(i)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-12-9c523c46633e> in <module>
#       2 error_floor_test1_fit = []
#       3 error_area_test1_fit = []
# ----> 4 predict_floor_argmax_test1_fit = predict_floor_test1_fit.argmax(axis = 1)
#       5 predict_building_argmax_test1_fit = predict_building_test1_fit.argmax(axis = 1)
#       6 predict_area_argmax_test1_fit = predict_area_test1_fit.argmax(axis = 1)
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
error_rate_floor_test1_fit = len(error_floor_test1_fit) / len(predict_floor_test1_fit)
print('error_rate_floor_test1_fit: ', error_rate_floor_test1_fit)
error_rate_building_test1_fit = len(error_building_test1_fit) / len(predict_building_test1_fit)
print('error_rate_building_test1_fit: ', error_rate_building_test1_fit)
error_rate_area_test1_fit = len(error_area_test1_fit) / len(predict_area_test1_fit)
print('error_rate_area_test1_fit', error_rate_area_test1_fit)

# %%
error_distance_test1_fit = []
for i in range(len(predict_long_test1_fit)):
    error_distance_test1_fit.append(euclidean_distance(predict_lat_test1_fit[i], predict_long_test1_fit[i], y_test1[i, 1], y_test1[i, 0]))
error_mean_distance_test1_fit = np.mean(np.stack(error_distance_test1_fit)).item()
error_max_distance_test1_fit = np.max(np.stack(error_distance_test1_fit)).item()
error_min_distance_test1_fit = np.min(np.stack(error_distance_test1_fit)).item()
error_std_distance_test1_fit = np.std(np.stack(error_distance_test1_fit)).item()
error_var_distance_test1_fit = np.var(np.stack(error_distance_test1_fit)).item()
print('error_mean_distance_test1_fit: ', error_mean_distance_test1_fit)
print('error_max_distance_test1_fit: ', error_max_distance_test1_fit)
print('error_min_distance_test1_fit: ', error_min_distance_test1_fit)
print('error_std_distance_test1_fit: ', error_std_distance_test1_fit)
print('error_var_distance_test1_fit: ', error_var_distance_test1_fit)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-04b3ebda792f> in <module>
#       1 error_distance_test1_fit = []
#       2 for i in range(len(predict_long_test1_fit) - 1):
# ----> 3     error_distance_test1_fit.append(euclidean_distance(predict_lat_test1_fit[i], predict_long_test1_fit[i], y_test1[i, 1], y_test1[i, 0]))
#       4 error_mean_distance_test1_fit = np.mean(np.stack(error_distance_test1_fit)).item()
#       5 error_max_distance_test1_fit = np.max(np.stack(error_distance_test1_fit)).item()
#
# IndexError: index 555 is out of bounds for axis 0 with size 555

# %%
print(len(predict_long_test1_fit))
# Out:
# 15948
