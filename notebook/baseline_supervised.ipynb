# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import lightgbm as lgb

class UJIDataset(torch.utils.data.Dataset):
    def __init__(self, root, train = True, transform = None, target_transform = None, download = False):
        self.root = root
        dir_path = self.root + '/UJIndoorLoc'
        zip_path = self.root + '/uji_uil.zip'
        dataset_training_file = dir_path + '/trainingData.csv'
        dataset_validation_file = dir_path + '/validationData.csv'
        # Load independent variables (WAPs values)
        if train:
            dataset_file = dataset_training_file
        else:
            dataset_file = dataset_validation_file
        file = open(dataset_file, 'r')
        # Load labels
        label = file.readline()
        label = label.split(',')
        # Load independent variables
        file_load = np.loadtxt(file, delimiter = ',', skiprows = 1)
        #file_load_label = np.loadtxt(file, delimiter = ',')
        #data = np.genfromtxt(file, dtype = float, delimiter = ',', names = True)
        # RSSI values
        self.x = file_load[:, 0 : 520]
        # Load dependent variables
        self.y = file_load[:, 520 : 524]
        # Divide labels into x and y
        self.x_label = label[0 : 520]
        self.x_label = np.concatenate([self.x_label, label[524: 529]])
        self.y_label = label[520 : 524]
        # Regularization of independent variables
        self.x[self.x == 100] = np.nan    # WAP not detected
        self.x = self.x + 104             # Convert into positive values
        self.x = self.x / 104             # Regularize into scale between 0 and 1
        # Building ID, Space ID, Relative Position, User ID, Phone ID and Timestamp respectively
        self.x = np.concatenate([self.x, file_load[:, 524 : 529]], axis = 1)
        file.close()
        # Reduce the number of dependent variables by combining building number and floor into one variable: area
        area = self.y[:, 3] * 5 + self.y[:, 2]
        self.y = np.column_stack((self.y, area))
    def to_tensor(self):
        self.x = torch.from_numpy(self.x).float()
        self.y = torch.from_numpy(self.y).float()
        self.area = torch.from_numpy(self.area).float()
    def nan_to_zero(self):
        self.x = np.nan_to_num(self.x)
    # Return the target instance (row)
    def __getitem__(self, index_row):
        return self.x[index_row, :], self.y[index_row, :]
    # Return the number of instances (the number of rows)
    def __len__(self, dim = 0):
        return int(self.x.size()[0])

# %%
# Calculate Euclidean distance (unit: meter) between two coordinates in EPSG:3857 
def euclidean_distance(latitude_1, longitude_1, latitude_2, longitude_2):
    return np.sqrt((latitude_1 - latitude_2)**2 + (longitude_1 - longitude_2)**2)

# %%
# Load training dataset
dataset_train = UJIDataset('./data', train = True)
dataset_test = UJIDataset('./data', train = False)
#gb_train_data = lgb.Dataset(

# %%
x_train, x_validate, y_train, y_validate = sklearn.model_selection.train_test_split(dataset_train.x, dataset_train.y, test_size = 0.2, random_state = 42)
x_test1, x_test2, y_test1, y_test2 = sklearn.model_selection.train_test_split(dataset_test.x, dataset_test.y, test_size = 0.5, random_state = 42)

# %%
dataset_train_reg_long_lgb = lgb.Dataset(x_train, label = y_train[:, 0])
dataset_validate_reg_long_lgb = lgb.Dataset(x_validate, label = y_validate[:, 0])
dataset_train_reg_lat_lgb = lgb.Dataset(x_train, label = y_train[:, 1])
dataset_validate_reg_lat_lgb = lgb.Dataset(x_validate, label = y_validate[:, 1])
dataset_train_cat_floor_lgb = lgb.Dataset(x_train, label = y_train[:, 2])
dataset_validate_cat_floor_lgb = lgb.Dataset(x_validate, label = y_validate[:, 2])
dataset_train_cat_building_lgb = lgb.Dataset(x_train, label = y_train[:, 3])
dataset_validate_cat_building_lgb = lgb.Dataset(x_validate, label = y_validate[:, 3])
dataset_train_cat_area_lgb = lgb.Dataset(x_train, label = y_train[:, 4])
dataset_validate_cat_area_lgb = lgb.Dataset(x_validate, label = y_validate[:, 4])

# %%
params_lgbr = {
              'boosting_type': 'rf',
              'bagging_freq': 5,
              'bagging_fraction': 0.8,
              'num_leaves': 1440,  
              'learning_rate': 0.001,
              'max_depth': -1,
              'objective': 'regression'
              #'seed':2018
              }

params_lgbr_long_fit = {'eval_set': [(x_validate, y_validate[:, 0])],
                        'eval_names': ['evalset_long'],
                        'eval_metric': ['rmse'],
                        #'early_stoppping_rounds': [100],
                       }

params_lgbr_lat_fit = {'eval_set': [(x_validate, y_validate[:, 1])],
                        'eval_names': ['evalset_lat'],
                        'eval_metric': ['rmse'],
                        #'early_stoppping_rounds': [100],
                       }

params_lgbc = {'boosting_type': 'rf',
               'bagging_freq': 5,
               'bagging_fraction': 0.8,
               'num_leaves': 144,  
               'learning_rate': 0.002,
               'max_depth': -1,
               'objective': 'multiclass'
              }

params_lgbc_floor_fit = {'eval_set': [(x_validate, y_validate[:, 2])],
                         'eval_names': ['evalset_floor'],
                         'eval_metric': ['multi_logloss'],
                         #'early_stopping_rounds': [100],
                        }

params_lgbc_building_fit = {'eval_set': [(x_validate, y_validate[:, 3])],
                            'eval_names': ['evalset_building'],
                            'eval_metric': ['multi_logloss'],
                            #'early_stoppping_rounds': [100],
                           }



params_lgbc_area_fit = {'eval_set': [(x_validate, y_validate[:, 4])],
                        'eval_names': ['evalset_area'],
                        'eval_metric': ['multi_logloss'],
                        #'early_stopping_rounds': [100],
                       }

# %%
print(y_validate[:,4])
# Out:
# [ 7.  7. 13. ...  7.  5. 13.]

# %%
lgbr_long = lgb.LGBMRegressor(**params_lgbr)
lgbr_lat = lgb.LGBMRegressor(**params_lgbr)
lgbc_floor = lgb.LGBMClassifier(**params_lgbc)
lgbc_building = lgb.LGBMClassifier(**params_lgbc)
lgbc_area = lgb.LGBMClassifier(**params_lgbc)

model_reg_long_lgb_fit = lgbr_long.fit(X = x_train, y = y_train[:, 0], **params_lgbr_long_fit, early_stopping_rounds = 100)
model_reg_lat_lgb_fit = lgbr_lat.fit(X = x_train, y = y_train[:, 1], **params_lgbr_lat_fit, early_stopping_rounds = 100)
model_cat_floor_lgb_fit = lgbc_floor.fit(X = x_train, y = y_train[:, 2], **params_lgbc_floor_fit, early_stopping_rounds = 100)
model_cat_building_lgb_fit = lgbc_building.fit(X = x_train, y = y_train[:, 3], **params_lgbc_building_fit, early_stopping_rounds = 100)
model_cat_area_lgb_fit = lgbc_area.fit(X = x_train, y = y_train[:, 4], **params_lgbc_area_fit, early_stopping_rounds = 100)
# Out:
# [1]	evalset_long's rmse: 7.74875	evalset_long's l2: 60.0432
# Training until validation scores don't improve for 100 rounds
# [2]	evalset_long's rmse: 7.74875	evalset_long's l2: 60.0432
# [3]	evalset_long's rmse: 7.74875	evalset_long's l2: 60.0432
# [4]	evalset_long's rmse: 7.74875	evalset_long's l2: 60.0432
# [5]	evalset_long's rmse: 7.74875	evalset_long's l2: 60.0432
# [6]	evalset_long's rmse: 7.10206	evalset_long's l2: 50.4393
# [7]	evalset_long's rmse: 6.78125	evalset_long's l2: 45.9853
# [8]	evalset_long's rmse: 6.63028	evalset_long's l2: 43.9606
# [9]	evalset_long's rmse: 6.57005	evalset_long's l2: 43.1655
# [10]	evalset_long's rmse: 6.55901	evalset_long's l2: 43.0207
# [11]	evalset_long's rmse: 6.41496	evalset_long's l2: 41.1517
# [12]	evalset_long's rmse: 6.34208	evalset_long's l2: 40.2219
# [13]	evalset_long's rmse: 6.31513	evalset_long's l2: 39.8809
# [14]	evalset_long's rmse: 6.31773	evalset_long's l2: 39.9137
# [15]	evalset_long's rmse: 6.33916	evalset_long's l2: 40.185
# [16]	evalset_long's rmse: 6.24881	evalset_long's l2: 39.0476
# [17]	evalset_long's rmse: 6.19268	evalset_long's l2: 38.3492
# [18]	evalset_long's rmse: 6.16187	evalset_long's l2: 37.9687
# [19]	evalset_long's rmse: 6.14979	evalset_long's l2: 37.8199
# [20]	evalset_long's rmse: 6.15148	evalset_long's l2: 37.8407
# [21]	evalset_long's rmse: 6.09751	evalset_long's l2: 37.1797
# [22]	evalset_long's rmse: 6.06206	evalset_long's l2: 36.7486
# [23]	evalset_long's rmse: 6.04121	evalset_long's l2: 36.4963
# [24]	evalset_long's rmse: 6.03187	evalset_long's l2: 36.3834
# [25]	evalset_long's rmse: 6.03155	evalset_long's l2: 36.3796
# [26]	evalset_long's rmse: 5.97897	evalset_long's l2: 35.7481
# [27]	evalset_long's rmse: 5.93938	evalset_long's l2: 35.2763
# [28]	evalset_long's rmse: 5.91061	evalset_long's l2: 34.9353
# [29]	evalset_long's rmse: 5.89084	evalset_long's l2: 34.702
# [30]	evalset_long's rmse: 5.87856	evalset_long's l2: 34.5574
# [31]	evalset_long's rmse: 5.88672	evalset_long's l2: 34.6534
# [32]	evalset_long's rmse: 5.90168	evalset_long's l2: 34.8298
# [33]	evalset_long's rmse: 5.92213	evalset_long's l2: 35.0717
# [34]	evalset_long's rmse: 5.94699	evalset_long's l2: 35.3667
# [35]	evalset_long's rmse: 5.97535	evalset_long's l2: 35.7048
# [36]	evalset_long's rmse: 5.96945	evalset_long's l2: 35.6343
# [37]	evalset_long's rmse: 5.9688	evalset_long's l2: 35.6266
# [38]	evalset_long's rmse: 5.9726	evalset_long's l2: 35.672
# [39]	evalset_long's rmse: 5.98018	evalset_long's l2: 35.7625
# [40]	evalset_long's rmse: 5.99094	evalset_long's l2: 35.8914
# [41]	evalset_long's rmse: 5.9695	evalset_long's l2: 35.6349
# [42]	evalset_long's rmse: 5.95304	evalset_long's l2: 35.4387
# [43]	evalset_long's rmse: 5.941	evalset_long's l2: 35.2954
# [44]	evalset_long's rmse: 5.93283	evalset_long's l2: 35.1985
# [45]	evalset_long's rmse: 5.92808	evalset_long's l2: 35.1422
# [46]	evalset_long's rmse: 5.93172	evalset_long's l2: 35.1852
# [47]	evalset_long's rmse: 5.93809	evalset_long's l2: 35.2609
# [48]	evalset_long's rmse: 5.94684	evalset_long's l2: 35.3649
# [49]	evalset_long's rmse: 5.95766	evalset_long's l2: 35.4937
# [50]	evalset_long's rmse: 5.97027	evalset_long's l2: 35.6441
# [51]	evalset_long's rmse: 5.96698	evalset_long's l2: 35.6049
# [52]	evalset_long's rmse: 5.96673	evalset_long's l2: 35.6019
# [53]	evalset_long's rmse: 5.96919	evalset_long's l2: 35.6313
# [54]	evalset_long's rmse: 5.97406	evalset_long's l2: 35.6894
# [55]	evalset_long's rmse: 5.98106	evalset_long's l2: 35.7731
# [56]	evalset_long's rmse: 5.99674	evalset_long's l2: 35.9609
# [57]	evalset_long's rmse: 6.01336	evalset_long's l2: 36.1605
# [58]	evalset_long's rmse: 6.03077	evalset_long's l2: 36.3702
# [59]	evalset_long's rmse: 6.04887	evalset_long's l2: 36.5888
# [60]	evalset_long's rmse: 6.06754	evalset_long's l2: 36.815
# [61]	evalset_long's rmse: 6.07698	evalset_long's l2: 36.9297
# [62]	evalset_long's rmse: 6.08744	evalset_long's l2: 37.057
# [63]	evalset_long's rmse: 6.09882	evalset_long's l2: 37.1956
# [64]	evalset_long's rmse: 6.111	evalset_long's l2: 37.3443
# [65]	evalset_long's rmse: 6.12388	evalset_long's l2: 37.5019
# [66]	evalset_long's rmse: 6.12286	evalset_long's l2: 37.4894
# [67]	evalset_long's rmse: 6.12319	evalset_long's l2: 37.4934
# [68]	evalset_long's rmse: 6.12475	evalset_long's l2: 37.5125
# [69]	evalset_long's rmse: 6.12743	evalset_long's l2: 37.5454
# [70]	evalset_long's rmse: 6.13113	evalset_long's l2: 37.5908
# [71]	evalset_long's rmse: 6.13986	evalset_long's l2: 37.6979
# [72]	evalset_long's rmse: 6.14929	evalset_long's l2: 37.8137
# [73]	evalset_long's rmse: 6.15933	evalset_long's l2: 37.9373
# [74]	evalset_long's rmse: 6.16993	evalset_long's l2: 38.068
# [75]	evalset_long's rmse: 6.18102	evalset_long's l2: 38.205
# [76]	evalset_long's rmse: 6.17908	evalset_long's l2: 38.1811
# [77]	evalset_long's rmse: 6.17845	evalset_long's l2: 38.1733
# [78]	evalset_long's rmse: 6.17903	evalset_long's l2: 38.1804
# [79]	evalset_long's rmse: 6.18072	evalset_long's l2: 38.2013
# [80]	evalset_long's rmse: 6.18345	evalset_long's l2: 38.235
# [81]	evalset_long's rmse: 6.17727	evalset_long's l2: 38.1587
# [82]	evalset_long's rmse: 6.17219	evalset_long's l2: 38.0959
# [83]	evalset_long's rmse: 6.16813	evalset_long's l2: 38.0458
# [84]	evalset_long's rmse: 6.16503	evalset_long's l2: 38.0075
# [85]	evalset_long's rmse: 6.16282	evalset_long's l2: 37.9803
# [86]	evalset_long's rmse: 6.1618	evalset_long's l2: 37.9677
# [87]	evalset_long's rmse: 6.16154	evalset_long's l2: 37.9646
# [88]	evalset_long's rmse: 6.16199	evalset_long's l2: 37.9701
# [89]	evalset_long's rmse: 6.1631	evalset_long's l2: 37.9838
# [90]	evalset_long's rmse: 6.16483	evalset_long's l2: 38.0051
# [91]	evalset_long's rmse: 6.1631	evalset_long's l2: 37.9837
# [92]	evalset_long's rmse: 6.16214	evalset_long's l2: 37.9719
# [93]	evalset_long's rmse: 6.16191	evalset_long's l2: 37.9691
# [94]	evalset_long's rmse: 6.16236	evalset_long's l2: 37.9746
# [95]	evalset_long's rmse: 6.16345	evalset_long's l2: 37.9881
# [96]	evalset_long's rmse: 6.17335	evalset_long's l2: 38.1103
# [97]	evalset_long's rmse: 6.18365	evalset_long's l2: 38.2375
# [98]	evalset_long's rmse: 6.19431	evalset_long's l2: 38.3695
# [99]	evalset_long's rmse: 6.20531	evalset_long's l2: 38.5059
# [100]	evalset_long's rmse: 6.21661	evalset_long's l2: 38.6462
# Did not meet early stopping. Best iteration is:
# [30]	evalset_long's rmse: 5.87856	evalset_long's l2: 34.5574
# [1]	evalset_lat's rmse: 6.76066	evalset_lat's l2: 45.7065
# Training until validation scores don't improve for 100 rounds
# [2]	evalset_lat's rmse: 6.76066	evalset_lat's l2: 45.7065
# [3]	evalset_lat's rmse: 6.76066	evalset_lat's l2: 45.7065
# [4]	evalset_lat's rmse: 6.76066	evalset_lat's l2: 45.7065
# [5]	evalset_lat's rmse: 6.76066	evalset_lat's l2: 45.7065
# [6]	evalset_lat's rmse: 6.19823	evalset_lat's l2: 38.4181
# [7]	evalset_lat's rmse: 5.89721	evalset_lat's l2: 34.7771
# [8]	evalset_lat's rmse: 5.73605	evalset_lat's l2: 32.9023
# [9]	evalset_lat's rmse: 5.65254	evalset_lat's l2: 31.9512
# [10]	evalset_lat's rmse: 5.61337	evalset_lat's l2: 31.5099
# [11]	evalset_lat's rmse: 5.48978	evalset_lat's l2: 30.1377
# [12]	evalset_lat's rmse: 5.43028	evalset_lat's l2: 29.4879
# [13]	evalset_lat's rmse: 5.41191	evalset_lat's l2: 29.2888
# [14]	evalset_lat's rmse: 5.41977	evalset_lat's l2: 29.3739
# [15]	evalset_lat's rmse: 5.44414	evalset_lat's l2: 29.6387
# [16]	evalset_lat's rmse: 5.41003	evalset_lat's l2: 29.2684
# [17]	evalset_lat's rmse: 5.39514	evalset_lat's l2: 29.1076
# [18]	evalset_lat's rmse: 5.39398	evalset_lat's l2: 29.0951
# [19]	evalset_lat's rmse: 5.40259	evalset_lat's l2: 29.188
# [20]	evalset_lat's rmse: 5.41809	evalset_lat's l2: 29.3557
# [21]	evalset_lat's rmse: 5.39473	evalset_lat's l2: 29.1031
# [22]	evalset_lat's rmse: 5.38269	evalset_lat's l2: 28.9733
# [23]	evalset_lat's rmse: 5.37939	evalset_lat's l2: 28.9379
# [24]	evalset_lat's rmse: 5.38285	evalset_lat's l2: 28.975
# [25]	evalset_lat's rmse: 5.39148	evalset_lat's l2: 29.0681
# [26]	evalset_lat's rmse: 5.4057	evalset_lat's l2: 29.2216
# [27]	evalset_lat's rmse: 5.42353	evalset_lat's l2: 29.4147
# [28]	evalset_lat's rmse: 5.44408	evalset_lat's l2: 29.638
# [29]	evalset_lat's rmse: 5.46662	evalset_lat's l2: 29.8839
# [30]	evalset_lat's rmse: 5.49058	evalset_lat's l2: 30.1465
# [31]	evalset_lat's rmse: 5.4878	evalset_lat's l2: 30.116
# [32]	evalset_lat's rmse: 5.48835	evalset_lat's l2: 30.122
# [33]	evalset_lat's rmse: 5.49165	evalset_lat's l2: 30.1582
# [34]	evalset_lat's rmse: 5.4972	evalset_lat's l2: 30.2192
# [35]	evalset_lat's rmse: 5.50462	evalset_lat's l2: 30.3008
# [36]	evalset_lat's rmse: 5.49783	evalset_lat's l2: 30.2261
# [37]	evalset_lat's rmse: 5.49389	evalset_lat's l2: 30.1828
# [38]	evalset_lat's rmse: 5.49239	evalset_lat's l2: 30.1664
# [39]	evalset_lat's rmse: 5.49297	evalset_lat's l2: 30.1727
# [40]	evalset_lat's rmse: 5.49534	evalset_lat's l2: 30.1987
# [41]	evalset_lat's rmse: 5.46066	evalset_lat's l2: 29.8188
# [42]	evalset_lat's rmse: 5.43167	evalset_lat's l2: 29.503
# [43]	evalset_lat's rmse: 5.40773	evalset_lat's l2: 29.2435
# [44]	evalset_lat's rmse: 5.38831	evalset_lat's l2: 29.0339
# [45]	evalset_lat's rmse: 5.37292	evalset_lat's l2: 28.8682
# [46]	evalset_lat's rmse: 5.34787	evalset_lat's l2: 28.5997
# [47]	evalset_lat's rmse: 5.32607	evalset_lat's l2: 28.3671
# [48]	evalset_lat's rmse: 5.30722	evalset_lat's l2: 28.1666
# [49]	evalset_lat's rmse: 5.29103	evalset_lat's l2: 27.995
# [50]	evalset_lat's rmse: 5.27725	evalset_lat's l2: 27.8493
# [51]	evalset_lat's rmse: 5.28568	evalset_lat's l2: 27.9384
# [52]	evalset_lat's rmse: 5.29504	evalset_lat's l2: 28.0374
# [53]	evalset_lat's rmse: 5.3052	evalset_lat's l2: 28.1452
# [54]	evalset_lat's rmse: 5.31606	evalset_lat's l2: 28.2605
# [55]	evalset_lat's rmse: 5.3275	evalset_lat's l2: 28.3823
# [56]	evalset_lat's rmse: 5.31553	evalset_lat's l2: 28.2549
# [57]	evalset_lat's rmse: 5.30503	evalset_lat's l2: 28.1433
# [58]	evalset_lat's rmse: 5.29586	evalset_lat's l2: 28.0462
# [59]	evalset_lat's rmse: 5.28793	evalset_lat's l2: 27.9622
# [60]	evalset_lat's rmse: 5.28112	evalset_lat's l2: 27.8902
# [61]	evalset_lat's rmse: 5.28793	evalset_lat's l2: 27.9622
# [62]	evalset_lat's rmse: 5.29536	evalset_lat's l2: 28.0408
# [63]	evalset_lat's rmse: 5.30332	evalset_lat's l2: 28.1252
# [64]	evalset_lat's rmse: 5.31176	evalset_lat's l2: 28.2148
# [65]	evalset_lat's rmse: 5.32061	evalset_lat's l2: 28.3089
# [66]	evalset_lat's rmse: 5.32731	evalset_lat's l2: 28.3802
# [67]	evalset_lat's rmse: 5.33443	evalset_lat's l2: 28.4561
# [68]	evalset_lat's rmse: 5.34193	evalset_lat's l2: 28.5362
# [69]	evalset_lat's rmse: 5.34977	evalset_lat's l2: 28.62
# [70]	evalset_lat's rmse: 5.3579	evalset_lat's l2: 28.7071
# [71]	evalset_lat's rmse: 5.34714	evalset_lat's l2: 28.5919
# [72]	evalset_lat's rmse: 5.33758	evalset_lat's l2: 28.4898
# [73]	evalset_lat's rmse: 5.32915	evalset_lat's l2: 28.3999
# [74]	evalset_lat's rmse: 5.32177	evalset_lat's l2: 28.3212
# [75]	evalset_lat's rmse: 5.31536	evalset_lat's l2: 28.2531
# [76]	evalset_lat's rmse: 5.31528	evalset_lat's l2: 28.2522
# [77]	evalset_lat's rmse: 5.31592	evalset_lat's l2: 28.259
# [78]	evalset_lat's rmse: 5.31723	evalset_lat's l2: 28.273
# [79]	evalset_lat's rmse: 5.31917	evalset_lat's l2: 28.2936
# [80]	evalset_lat's rmse: 5.32168	evalset_lat's l2: 28.3203
# [81]	evalset_lat's rmse: 5.32684	evalset_lat's l2: 28.3752
# [82]	evalset_lat's rmse: 5.33227	evalset_lat's l2: 28.4331
# [83]	evalset_lat's rmse: 5.33793	evalset_lat's l2: 28.4935
# [84]	evalset_lat's rmse: 5.34381	evalset_lat's l2: 28.5564
# [85]	evalset_lat's rmse: 5.34989	evalset_lat's l2: 28.6214
# [86]	evalset_lat's rmse: 5.35424	evalset_lat's l2: 28.6679
# [87]	evalset_lat's rmse: 5.35884	evalset_lat's l2: 28.7172
# [88]	evalset_lat's rmse: 5.36369	evalset_lat's l2: 28.7692
# [89]	evalset_lat's rmse: 5.36875	evalset_lat's l2: 28.8235
# [90]	evalset_lat's rmse: 5.37402	evalset_lat's l2: 28.8801
# [91]	evalset_lat's rmse: 5.37727	evalset_lat's l2: 28.9151
# [92]	evalset_lat's rmse: 5.38092	evalset_lat's l2: 28.9542
# [93]	evalset_lat's rmse: 5.38491	evalset_lat's l2: 28.9973
# [94]	evalset_lat's rmse: 5.38923	evalset_lat's l2: 29.0438
# [95]	evalset_lat's rmse: 5.39386	evalset_lat's l2: 29.0937
# [96]	evalset_lat's rmse: 5.39646	evalset_lat's l2: 29.1218
# [97]	evalset_lat's rmse: 5.39944	evalset_lat's l2: 29.154
# [98]	evalset_lat's rmse: 5.40279	evalset_lat's l2: 29.1901
# [99]	evalset_lat's rmse: 5.40647	evalset_lat's l2: 29.2299
# [100]	evalset_lat's rmse: 5.41046	evalset_lat's l2: 29.2731
# Did not meet early stopping. Best iteration is:
# [50]	evalset_lat's rmse: 5.27725	evalset_lat's l2: 27.8493
# [1]	evalset_floor's multi_logloss: 0.260291
# Training until validation scores don't improve for 100 rounds
# [2]	evalset_floor's multi_logloss: 0.260291
# [3]	evalset_floor's multi_logloss: 0.260291
# [4]	evalset_floor's multi_logloss: 0.260291
# [5]	evalset_floor's multi_logloss: 0.260291
# [6]	evalset_floor's multi_logloss: 0.25766
# [7]	evalset_floor's multi_logloss: 0.256747
# [8]	evalset_floor's multi_logloss: 0.256609
# [9]	evalset_floor's multi_logloss: 0.256831
# [10]	evalset_floor's multi_logloss: 0.257217
# [11]	evalset_floor's multi_logloss: 0.255829
# [12]	evalset_floor's multi_logloss: 0.254982
# [13]	evalset_floor's multi_logloss: 0.254497
# [14]	evalset_floor's multi_logloss: 0.254257
# [15]	evalset_floor's multi_logloss: 0.254186
# [16]	evalset_floor's multi_logloss: 0.253652
# [17]	evalset_floor's multi_logloss: 0.253293
# [18]	evalset_floor's multi_logloss: 0.253063
# [19]	evalset_floor's multi_logloss: 0.252931
# [20]	evalset_floor's multi_logloss: 0.252874
# [21]	evalset_floor's multi_logloss: 0.25257
# [22]	evalset_floor's multi_logloss: 0.252356
# [23]	evalset_floor's multi_logloss: 0.252214
# [24]	evalset_floor's multi_logloss: 0.252128
# [25]	evalset_floor's multi_logloss: 0.252087
# [26]	evalset_floor's multi_logloss: 0.251873
# [27]	evalset_floor's multi_logloss: 0.251731
# [28]	evalset_floor's multi_logloss: 0.251649
# [29]	evalset_floor's multi_logloss: 0.251619
# [30]	evalset_floor's multi_logloss: 0.25163
# [31]	evalset_floor's multi_logloss: 0.251289
# [32]	evalset_floor's multi_logloss: 0.251
# [33]	evalset_floor's multi_logloss: 0.250756
# [34]	evalset_floor's multi_logloss: 0.250552
# [35]	evalset_floor's multi_logloss: 0.250382
# [36]	evalset_floor's multi_logloss: 0.249993
# [37]	evalset_floor's multi_logloss: 0.249648
# [38]	evalset_floor's multi_logloss: 0.249344
# [39]	evalset_floor's multi_logloss: 0.249075
# [40]	evalset_floor's multi_logloss: 0.248838
# [41]	evalset_floor's multi_logloss: 0.24891
# [42]	evalset_floor's multi_logloss: 0.248996
# [43]	evalset_floor's multi_logloss: 0.249094
# [44]	evalset_floor's multi_logloss: 0.249203
# [45]	evalset_floor's multi_logloss: 0.249321
# [46]	evalset_floor's multi_logloss: 0.249212
# [47]	evalset_floor's multi_logloss: 0.249124
# [48]	evalset_floor's multi_logloss: 0.249054
# [49]	evalset_floor's multi_logloss: 0.249
# [50]	evalset_floor's multi_logloss: 0.248961
# [51]	evalset_floor's multi_logloss: 0.249148
# [52]	evalset_floor's multi_logloss: 0.249338
# [53]	evalset_floor's multi_logloss: 0.249531
# [54]	evalset_floor's multi_logloss: 0.249726
# [55]	evalset_floor's multi_logloss: 0.249924
# [56]	evalset_floor's multi_logloss: 0.249919
# [57]	evalset_floor's multi_logloss: 0.249925
# [58]	evalset_floor's multi_logloss: 0.249941
# [59]	evalset_floor's multi_logloss: 0.249965
# [60]	evalset_floor's multi_logloss: 0.249998
# [61]	evalset_floor's multi_logloss: 0.250003
# [62]	evalset_floor's multi_logloss: 0.250017
# [63]	evalset_floor's multi_logloss: 0.25004
# [64]	evalset_floor's multi_logloss: 0.250069
# [65]	evalset_floor's multi_logloss: 0.250105
# [66]	evalset_floor's multi_logloss: 0.250015
# [67]	evalset_floor's multi_logloss: 0.249934
# [68]	evalset_floor's multi_logloss: 0.249862
# [69]	evalset_floor's multi_logloss: 0.249797
# [70]	evalset_floor's multi_logloss: 0.24974
# [71]	evalset_floor's multi_logloss: 0.249546
# [72]	evalset_floor's multi_logloss: 0.249364
# [73]	evalset_floor's multi_logloss: 0.249193
# [74]	evalset_floor's multi_logloss: 0.249034
# [75]	evalset_floor's multi_logloss: 0.248884
# [76]	evalset_floor's multi_logloss: 0.248906
# [77]	evalset_floor's multi_logloss: 0.248932
# [78]	evalset_floor's multi_logloss: 0.248962
# [79]	evalset_floor's multi_logloss: 0.248997
# [80]	evalset_floor's multi_logloss: 0.249035
# [81]	evalset_floor's multi_logloss: 0.248866
# [82]	evalset_floor's multi_logloss: 0.248705
# [83]	evalset_floor's multi_logloss: 0.248553
# [84]	evalset_floor's multi_logloss: 0.248407
# [85]	evalset_floor's multi_logloss: 0.24827
# [86]	evalset_floor's multi_logloss: 0.248292
# [87]	evalset_floor's multi_logloss: 0.248318
# [88]	evalset_floor's multi_logloss: 0.248347
# [89]	evalset_floor's multi_logloss: 0.248379
# [90]	evalset_floor's multi_logloss: 0.248414
# [91]	evalset_floor's multi_logloss: 0.248317
# [92]	evalset_floor's multi_logloss: 0.248226
# [93]	evalset_floor's multi_logloss: 0.248141
# [94]	evalset_floor's multi_logloss: 0.248061
# [95]	evalset_floor's multi_logloss: 0.247986
# [96]	evalset_floor's multi_logloss: 0.248004
# [97]	evalset_floor's multi_logloss: 0.248025
# [98]	evalset_floor's multi_logloss: 0.248047
# [99]	evalset_floor's multi_logloss: 0.248072
# [100]	evalset_floor's multi_logloss: 0.2481
# Did not meet early stopping. Best iteration is:
# [95]	evalset_floor's multi_logloss: 0.247986
# [1]	evalset_building's multi_logloss: 0.184279
# Training until validation scores don't improve for 100 rounds
# [2]	evalset_building's multi_logloss: 0.184279
# [3]	evalset_building's multi_logloss: 0.184279
# [4]	evalset_building's multi_logloss: 0.184279
# [5]	evalset_building's multi_logloss: 0.184279
# [6]	evalset_building's multi_logloss: 0.183616
# [7]	evalset_building's multi_logloss: 0.183288
# [8]	evalset_building's multi_logloss: 0.183125
# [9]	evalset_building's multi_logloss: 0.183048
# [10]	evalset_building's multi_logloss: 0.183018
# [11]	evalset_building's multi_logloss: 0.182757
# [12]	evalset_building's multi_logloss: 0.18257
# [13]	evalset_building's multi_logloss: 0.182436
# [14]	evalset_building's multi_logloss: 0.182338
# [15]	evalset_building's multi_logloss: 0.182266
# [16]	evalset_building's multi_logloss: 0.182253
# [17]	evalset_building's multi_logloss: 0.182253
# [18]	evalset_building's multi_logloss: 0.182262
# [19]	evalset_building's multi_logloss: 0.182276
# [20]	evalset_building's multi_logloss: 0.182295
# [21]	evalset_building's multi_logloss: 0.182242
# [22]	evalset_building's multi_logloss: 0.1822
# [23]	evalset_building's multi_logloss: 0.182166
# [24]	evalset_building's multi_logloss: 0.182138
# [25]	evalset_building's multi_logloss: 0.182116
# [26]	evalset_building's multi_logloss: 0.182044
# [27]	evalset_building's multi_logloss: 0.181983
# [28]	evalset_building's multi_logloss: 0.181929
# [29]	evalset_building's multi_logloss: 0.181883
# [30]	evalset_building's multi_logloss: 0.181843
# [31]	evalset_building's multi_logloss: 0.181846
# [32]	evalset_building's multi_logloss: 0.181849
# [33]	evalset_building's multi_logloss: 0.181854
# [34]	evalset_building's multi_logloss: 0.18186
# [35]	evalset_building's multi_logloss: 0.181867
# [36]	evalset_building's multi_logloss: 0.181839
# [37]	evalset_building's multi_logloss: 0.181816
# [38]	evalset_building's multi_logloss: 0.181796
# [39]	evalset_building's multi_logloss: 0.18178
# [40]	evalset_building's multi_logloss: 0.181766
# [41]	evalset_building's multi_logloss: 0.181759
# [42]	evalset_building's multi_logloss: 0.181754
# [43]	evalset_building's multi_logloss: 0.181751
# [44]	evalset_building's multi_logloss: 0.181749
# [45]	evalset_building's multi_logloss: 0.181748
# [46]	evalset_building's multi_logloss: 0.181754
# [47]	evalset_building's multi_logloss: 0.181762
# [48]	evalset_building's multi_logloss: 0.18177
# [49]	evalset_building's multi_logloss: 0.181779
# [50]	evalset_building's multi_logloss: 0.181788
# [51]	evalset_building's multi_logloss: 0.181777
# [52]	evalset_building's multi_logloss: 0.181767
# [53]	evalset_building's multi_logloss: 0.181759
# [54]	evalset_building's multi_logloss: 0.181751
# [55]	evalset_building's multi_logloss: 0.181744
# [56]	evalset_building's multi_logloss: 0.181744
# [57]	evalset_building's multi_logloss: 0.181744
# [58]	evalset_building's multi_logloss: 0.181744
# [59]	evalset_building's multi_logloss: 0.181746
# [60]	evalset_building's multi_logloss: 0.181747
# [61]	evalset_building's multi_logloss: 0.181735
# [62]	evalset_building's multi_logloss: 0.181723
# [63]	evalset_building's multi_logloss: 0.181713
# [64]	evalset_building's multi_logloss: 0.181703
# [65]	evalset_building's multi_logloss: 0.181695
# [66]	evalset_building's multi_logloss: 0.181686
# [67]	evalset_building's multi_logloss: 0.181678
# [68]	evalset_building's multi_logloss: 0.18167
# [69]	evalset_building's multi_logloss: 0.181663
# [70]	evalset_building's multi_logloss: 0.181657
# [71]	evalset_building's multi_logloss: 0.181659
# [72]	evalset_building's multi_logloss: 0.181662
# [73]	evalset_building's multi_logloss: 0.181665
# [74]	evalset_building's multi_logloss: 0.181668
# [75]	evalset_building's multi_logloss: 0.181672
# [76]	evalset_building's multi_logloss: 0.181657
# [77]	evalset_building's multi_logloss: 0.181643
# [78]	evalset_building's multi_logloss: 0.18163
# [79]	evalset_building's multi_logloss: 0.181618
# [80]	evalset_building's multi_logloss: 0.181606
# [81]	evalset_building's multi_logloss: 0.181605
# [82]	evalset_building's multi_logloss: 0.181605
# [83]	evalset_building's multi_logloss: 0.181606
# [84]	evalset_building's multi_logloss: 0.181607
# [85]	evalset_building's multi_logloss: 0.181607
# [86]	evalset_building's multi_logloss: 0.181611
# [87]	evalset_building's multi_logloss: 0.181615
# [88]	evalset_building's multi_logloss: 0.181619
# [89]	evalset_building's multi_logloss: 0.181623
# [90]	evalset_building's multi_logloss: 0.181627
# [91]	evalset_building's multi_logloss: 0.181636
# [92]	evalset_building's multi_logloss: 0.181645
# [93]	evalset_building's multi_logloss: 0.181654
# [94]	evalset_building's multi_logloss: 0.181662
# [95]	evalset_building's multi_logloss: 0.181671
# [96]	evalset_building's multi_logloss: 0.181675
# [97]	evalset_building's multi_logloss: 0.181678
# [98]	evalset_building's multi_logloss: 0.181682
# [99]	evalset_building's multi_logloss: 0.181686
# [100]	evalset_building's multi_logloss: 0.181689
# Did not meet early stopping. Best iteration is:
# [81]	evalset_building's multi_logloss: 0.181605
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-233cebf31bc2> in <module>
#       9 model_cat_floor_lgb_fit = lgbc_floor.fit(X = x_train, y = y_train[:, 2], **params_lgbc_floor_fit, early_stopping_rounds = 100)
#      10 model_cat_building_lgb_fit = lgbc_building.fit(X = x_train, y = y_train[:, 3], **params_lgbc_building_fit, early_stopping_rounds = 100)
# ---> 11 model_cat_area_lgb_fit = lgbc_area.fit(X = x_train, y = y_train[:, 4], **params_lgbc_area_fit, early_stopping_rounds = 100)
#
# ~\AppData\Local\Continuum\anaconda3\envs\pytorch\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     786                     eval_set[i] = (valid_x, _y)
#     787                 else:
# --> 788                     eval_set[i] = (valid_x, self._le.transform(valid_y))
#     789
#     790         super(LGBMClassifier, self).fit(X, _y, sample_weight=sample_weight,
#
# ~\AppData\Local\Continuum\anaconda3\envs\pytorch\lib\site-packages\sklearn\preprocessing\label.py in transform(self, y)
#     255             return np.array([])
#     256
# --> 257         _, y = _encode(y, uniques=self.classes_, encode=True)
#     258         return y
#     259
#
# ~\AppData\Local\Continuum\anaconda3\envs\pytorch\lib\site-packages\sklearn\preprocessing\label.py in _encode(values, uniques, encode)
#     108         return res
#     109     else:
# --> 110         return _encode_numpy(values, uniques, encode)
#     111
#     112
#
# ~\AppData\Local\Continuum\anaconda3\envs\pytorch\lib\site-packages\sklearn\preprocessing\label.py in _encode_numpy(values, uniques, encode)
#      47         if diff:
#      48             raise ValueError("y contains previously unseen labels: %s"
# ---> 49                              % str(diff))
#      50         encoded = np.searchsorted(uniques, values)
#      51         return uniques, encoded
#
# ValueError: y contains previously unseen labels: [4, 9]

# %%
predict_long_test1_fit = model_reg_long_lgb_fit.predict(x_test1)
predict_lat_test1_fit = model_reg_lat_lgb_fit.predict(x_test1)
predict_floor_test1_fit = model_cat_floor_lgb_fit.predict(x_test1)
predict_building_test1_fit = model_cat_building_lgb_fit.predict(x_test1)
predict_area_test1_fit = model_cat_area_lgb_fit.predict(x_test1)

# %%
print(predict_building_test1_fit)
# Out:
# [ 7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.
#   7.  7.  7.  7.  7.  7.  8.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.
#   7.  7.  7.  7.  7.  7.  7.  7.  7. 14.  7.  7.  7.  7. 14.  7.  7.  7.
#   7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.
#   7.  7.  7.  7.  7. 14.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.
#   7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.
#   7.  7.  0.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.
#   7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  0.  7.  7.  7.  7.  7.
#   7.  7.  8.  7.  7.  7.  7.  7.  7.  7.  7.  7. 14. 14.  3.  7.  7.  7.
#   7.  7.  7. 14.  7.  7.  0.  7.  7.  7.  7.  7.  7. 14.  7.  8.  7.  7.
#   7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.
#   7.  8.  7.  7.  7.  7. 14.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  8.
#   7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.
#   7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  0.
#   7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  0.  0.  7.  7.  7.  7.  7.  7.
#   7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  3.  7.  7.
#   0.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.
#   7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7. 14.  7.  7.
#   7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  3.  7.  7.  7.  7.  8.
#   7.  7.  7.  7. 14.  7.  0.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.
#   7.  7.  7.  7.  7.  7.  7.  7.  7.  7. 14.  7.  7.  7.  7.  7.  7.  7.
#   7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.
#   7.  7.  0.  3.  7. 14.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.
#   7.  7.  7.  7.  7.  7.  7.  7.  7.  7. 14.  7.  3.  7.  7.  7.  3.  7.
#   7. 14.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.
#   7.  7.  7.  7.  7.  7.  7.  7.  7. 14.  7.  7.  7.  0.  7.  7.  7.  7.
#   7.  7.  7.  8.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.
#   7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  3.  7.  7.
#   7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.
#   7.  7.  7.  7.  7.  0.  7.  7.  7.  7.  0.  7.  7.  7.  7.  7. 14.  7.
#   7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.  7.]

# %%
error_building_test1_fit = []
error_floor_test1_fit = []
error_area_test1_fit = []
predict_floor_argmax_test1_fit = predict_floor_test1_fit.argmax(axis = 1)
predict_building_argmax_test1_fit = predict_building_test1_fit.argmax(axis = 1)
predict_area_argmax_test1_fit = predict_area_test1_fit.argmax(axis = 1)
for i in range(len(predict_floor_test1_fit)):
    if predict_floor_argmax_test1_fit[i] != y_test1[i, 2]:
        error_floor_test1_fit.append(i)
    if predict_building_argmax_test1_fit[i] != y_test1[i, 3]:
        error_building_test1_fit.append(i)
    if predict_area_argmax_test1_fit[i] != y_test1[i, 4]:
        error_area_test1_fit.append(i)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-9-9c523c46633e> in <module>
#       2 error_floor_test1_fit = []
#       3 error_area_test1_fit = []
# ----> 4 predict_floor_argmax_test1_fit = predict_floor_test1_fit.argmax(axis = 1)
#       5 predict_building_argmax_test1_fit = predict_building_test1_fit.argmax(axis = 1)
#       6 predict_area_argmax_test1_fit = predict_area_test1_fit.argmax(axis = 1)
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
error_rate_floor_test1_fit = len(error_floor_test1_fit) / len(predict_floor_test1_fit)
print('error_rate_floor_test1_fit: ', error_rate_floor_test1_fit)
error_rate_building_test1_fit = len(error_building_test1_fit) / len(predict_building_test1_fit)
print('error_rate_building_test1_fit: ', error_rate_building_test1_fit)
error_rate_area_test1_fit = len(error_area_test1_fit) / len(predict_area_test1_fit)
print('error_rate_area_test1_fit', error_rate_area_test1_fit)

# %%
error_distance_test1_fit = []
for i in range(len(predict_long_test1_fit)):
    error_distance_test1_fit.append(euclidean_distance(predict_lat_test1_fit[i], predict_long_test1_fit[i], y_test1[i, 1], y_test1[i, 0]))
error_mean_distance_test1_fit = np.mean(np.stack(error_distance_test1_fit)).item()
error_max_distance_test1_fit = np.max(np.stack(error_distance_test1_fit)).item()
error_min_distance_test1_fit = np.min(np.stack(error_distance_test1_fit)).item()
error_std_distance_test1_fit = np.std(np.stack(error_distance_test1_fit)).item()
error_var_distance_test1_fit = np.var(np.stack(error_distance_test1_fit)).item()
print('error_mean_distance_test1_fit: ', error_mean_distance_test1_fit)
print('error_max_distance_test1_fit: ', error_max_distance_test1_fit)
print('error_min_distance_test1_fit: ', error_min_distance_test1_fit)
print('error_std_distance_test1_fit: ', error_std_distance_test1_fit)
print('error_var_distance_test1_fit: ', error_var_distance_test1_fit)
